# %% [markdown]
# <a href="https://colab.research.google.com/github/rally-adty/UNSIA-Data-Sciense-SM-4/blob/main/Pertemuan1_M_Rally_Adityo_240401010212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pertemuan 1 – Pengenalan Data Science
#
# **Nama Lengkap :** Maulana Rally Adityo
#
# **NIM :** (240401010212)
#
# **Kelas :** (IF401)
#
# Program Studi Informatika

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "M Rally"
angkatan = 2024
ipk = 3.75
aktif = True

print("Nama :", nama)
print("Angkatan :", angkatan)
print("IPK :", ipk)
print("Aktif :", aktif)
# Out:
# Nama : M Rally
# Angkatan : 2024
# IPK : 3.75
# Aktif : True

# %% [markdown]
# | Variabel | Tipe Data | Nilai   |
# | -------- | --------- | ------- |
# | nama     | String    | M Rally |
# | angkatan | Integer   | 2024    |
# | ipk      | Float     | 3.75    |
# | aktif    | Boolean   | True    |

# %%
tools = [
    "Python",
    "Google Colab",
    "Jupyter Notebook",
    "GitHub"
]

print(tools)
# Out:
# ['Python', 'Google Colab', 'Jupyter Notebook', 'GitHub']

# %% [markdown]
# List digunakan untuk menyimpan banyak data dalam satu variabel.
#
# Contoh:
#
# buah = ["Apel", "Jeruk", "Mangga"]

# %%
tools = [
    "Python",
    "Google Colab",
    "Jupyter Notebook",
    "GitHub"
]

print("Tools Data Science yang akan dipelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan dipelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %% [markdown]
# Perulangan digunakan untuk menjalankan perintah secara berulang.
#
# Struktur:
#
# for variabel in data:
#     perintah

# %%
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan(
    "M Rally",
    "Informatika",
    2024
)

print(hasil)
# Out:
# Hai! Saya M Rally dari Informatika, angkatan 2024.

# %% [markdown]
# Fungsi digunakan agar kode dapat dipakai berulang kali.
#
# Struktur:
#
# def nama_fungsi(parameter):
#     perintah

# %% [markdown]
# # Kesimpulan
#
# Pada praktikum ini saya mempelajari dasar-dasar Data Science menggunakan Google Colab sebagai lingkungan kerja berbasis cloud. Saya juga mempelajari konsep dasar Python seperti penggunaan output, variabel, tipe data, list, perulangan, dan fungsi.
#
# Temuan utama dari praktikum ini adalah Google Colab memudahkan proses belajar karena tidak memerlukan instalasi tambahan dan kode dapat dijalankan langsung melalui browser.
#
# Keterbatasan pada praktikum ini adalah materi masih bersifat pengenalan sehingga belum membahas analisis data yang lebih kompleks. Pertanyaan yang muncul adalah bagaimana konsep-konsep dasar Python ini akan diterapkan pada pengolahan data dan machine learning pada pertemuan selanjutnya.
